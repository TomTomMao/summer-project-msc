# %%
import pandas as pd

# %%
df = pd.read_csv('./transaction_cleanedtest copy.csv')

# %%
df.groupby('Transaction Date').count().sort_values(by='Transaction Number', ascending=False)
# Out:
#                   Unnamed: 0  Transaction Number  Transaction Type  \
# Transaction Date
# 21/10/2019                28                  28                28
# 19/08/2019                26                  26                26
# 04/01/2022                23                  23                22
# 07/02/2022                22                  22                22
# 01/06/2021                22                  22                21
# ...                      ...                 ...               ...
# 07/06/2017                 1                   1                 1
# 07/06/2022                 1                   1                 1
# 07/07/2020                 1                   1                 1
# 07/07/2022                 1                   1                 1
# 30/12/2016                 1                   1                 1
#
#                   Transaction Description  Debit Amount  Credit Amount  \
# Transaction Date
# ...

# %%
# Out:
# <module 'pandas' from 'C:\\Users\\84515\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\pandas\\__init__.py'>
